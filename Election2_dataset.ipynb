# %%
import pandas as pd
from io import StringIO

# %%
# Read in election csv
csv =  "Resources/elec_results_2020.csv"
elec_df = pd.read_csv(csv)
elec_df.head()
# Out:
#    state_fips  state_name  red_blue_2020
# 0           1     ALABAMA              1
# 1           2      ALASKA              1
# 2           4     ARIZONA              0
# 3           5    ARKANSAS              1
# 4           6  CALIFORNIA              0

# %%
elec_df["elec_result"] = elec_df["red_blue_2020"]

# %%
elec_df.head()
# Out:
#    state_fips  state_name  red_blue_2020  elec_result
# 0           1     ALABAMA              1            1
# 1           2      ALASKA              1            1
# 2           4     ARIZONA              0            0
# 3           5    ARKANSAS              1            1
# 4           6  CALIFORNIA              0            0

# %%
elec_df1 = elec_df.copy()

# %%
elec_df1.head()
# Out:
#    state_fips  state_name  red_blue_2020  elec_result
# 0           1     ALABAMA              1            1
# 1           2      ALASKA              1            1
# 2           4     ARIZONA              0            0
# 3           5    ARKANSAS              1            1
# 4           6  CALIFORNIA              0            0

# %%
elec_df1 = elec_df1[["state_name", "elec_result"]]

# %%
elec_df1.head()
# Out:
#    state_name  elec_result
# 0     ALABAMA            1
# 1      ALASKA            1
# 2     ARIZONA            0
# 3    ARKANSAS            1
# 4  CALIFORNIA            0

# %%
elec_df1.value_counts()
# Out:
# state_name            elec_result
# ALABAMA               1              1
# PENNSYLVANIA          0              1
# NEVADA                0              1
# NEW HAMPSHIRE         0              1
# NEW JERSEY            0              1
# NEW MEXICO            0              1
# NEW YORK              0              1
# NORTH CAROLINA        1              1
# NORTH DAKOTA          1              1
# OHIO                  1              1
# OKLAHOMA              1              1
# OREGON                0              1
# RHODE ISLAND          0              1
# MONTANA               1              1
# SOUTH CAROLINA        1              1
# SOUTH DAKOTA          1              1
# TENNESSEE             1              1
# TEXAS                 1              1
# UTAH                  1              1
# VERMONT               0              1
# VIRGINIA              0              1
# WASHINGTON            0              1
# WEST VIRGINIA         1              1
# WISCONSIN             0              1
# NEBRASKA              1              1
# MISSOURI              1              1
# ALASKA                1              1
# IDAHO                 1              1
# ARIZONA               0              1
# ARKANSAS              1              1
# CALIFORNIA            0              1
# COLORADO              0              1
# CONNECTICUT           0              1
# DELAWARE              0              1
# DISTRICT OF COLOMBIA  0              1
# FLORIDA               1              1
# GEORGIA               0              1
# HAWAII                0              1
# ILLINOIS              0              1
# MISSISSIPPI           1              1
# INDIANA               1              1
# IOWA                  1              1
# KANSAS                1              1
# KENTUCKY              1              1
# LOUISIANA             1              1
# MAINE                 0              1
# MARYLAND              0              1
# MASSACHUSETTS         0              1
# MICHIGAN              0              1
# MINNESOTA             0              1
# WYOMING               1              1
# dtype: int64

# %%
elec_df1[elec_df1["state_name"] ==  "WYOMING"]["elec_result"]
# Out:
# 50    1
# Name: elec_result, dtype: int64

# %%
elec_df1.head()
# Out:
#    state_name  elec_result
# 0     ALABAMA            1
# 1      ALASKA            1
# 2     ARIZONA            0
# 3    ARKANSAS            1
# 4  CALIFORNIA            0

# %%
file = "county_pop_merge.csv"
df = pd.read_csv(file)
df = df.dropna(subset=['state_name'])
df.head()
# Out:
#    state_fips state_name  fips          county_name  mask_mandate  \
# 0           1  ALABAMA    1001   Autauga County                 0
# 1           1  ALABAMA    1003  Baldwin County                  1
# 2           1  ALABAMA    1005   Barbour County                 0
# 3           1  ALABAMA    1007      Bibb County                 0
# 4           1  ALABAMA    1009    Blount County                 0
#
#    month_started  mandate_duration_months        date   county    state  \
# 0              0                        0  2020-12-31  Autauga  Alabama
# 1              7                        5  2020-12-31  Baldwin  Alabama
# 2              0                        0  2020-12-31  Barbour  Alabama
# 3              0                        0  2020-12-31     Bibb  Alabama
# 4              0                        0  2020-12-31   Blount  Alabama
#
#    cases  deaths  popestimate2020
# 0   4190      48            56145
# 1  13601     161           229287
# 2   1514      32            24589
# 3   1834      46            22136
# 4   4641      63            57879

# %%
df_dummy = df.copy()

# %%
df['state_name'] = df['state_name'].apply(lambda x: x.strip())
df['e_results'] = ''

for i in df.index:
    state = df.loc[i, 'state_name']
    try:
        df['e_results'].at[i] = elec_df1[elec_df1['state_name'].str.strip() == state.strip()]['elec_result'].values[0]
    except Exception as e:
        print(e)
    
df.sample(n=20)
# Out:
# index 0 is out of bounds for axis 0 with size 0
#       state_fips      state_name   fips             county_name  mask_mandate  \
# 2901          51        VIRGINIA  51550     Chesapeake city                 1
# 631           17        ILLINOIS  17097         Lake County                 1
# 663           17        ILLINOIS  17161   Rock Island County                0
# 1182          24        MARYLAND  24003  Anne Arundel County                1
# 601           17        ILLINOIS  17037       DeKalb County                 0
# 966           20          KANSAS  20181      Sherman County                 0
# 955           20          KANSAS  20159         Rice County                 0
# 2674          48           TEXAS  48339   Montgomery County                 1
# 1556          29        MISSOURI  29171       Putnam County                 0
# 1954          37  NORTH CAROLINA  37163      Sampson County                 1
# 523           13         GEORGIA  13301       Warren County                 0
# 2690          48           TEXAS  48371        Pecos County                 1
# 580           16           IDAHO  16083    Twin Falls County                0
# 2187          40        OKLAHOMA  40145      Wagoner County                 0
# 727           18         INDIANA  18085    Kosciusko County                 0
# 2336          45  SOUTH CAROLINA  45073       Oconee County                 0
# 1571          29        MISSOURI  29203      Shannon County                 0
# 2287          42    PENNSYLVANIA  42119        Union County                 1
# 2164          48           TEXAS  48009       Archer County                 0
# 1867          36        NEW YORK  36113       Warren County                 0
#
#       month_started  mandate_duration_months        date           county  \
# 2901              5                        7  2020-12-31  Chesapeake city
# 631               7                        5  2020-12-31             Lake
# 663               0                        0  2020-12-31      Rock Island
# 1182              4                        8  2020-12-31     Anne Arundel
# ARIZONA               0             15
# VERMONT               0             14
# MASSACHUSETTS         0             14
# NEW HAMPSHIRE         0             10
# CONNECTICUT           0              8
# RHODE ISLAND          0              5
# HAWAII                0              5
# DELAWARE              0              3
# DISTRICT OF COLUMBIA                 1
# dtype: int64

# %%
df.columns
# Out:
# Index(['state_fips', 'state_name', 'fips', 'county_name', 'mask_mandate',
#        'month_started', 'mandate_duration_months', 'date', 'county', 'state',
#        'cases', 'deaths', 'popestimate2020', 'e_results'],
#       dtype='object')

# %%
#df = df.drop(columns=['Index'])

# %%
df.sample(n=10)
# Out:
#       state_fips    state_name   fips              county_name  mask_mandate  \
# 295            8      COLORADO   8123          Weld County                 0
# 2384          46  SOUTH DAKOTA  46077     Kingsbury County                 0
# 2691          48         TEXAS  48373          Polk County                 1
# 914           20        KANSAS  20077        Harper County                 0
# 1363          27     MINNESOTA  27123        Ramsey County                 1
# 2375          46  SOUTH DAKOTA  46059          Hand County                 0
# 2376          46  SOUTH DAKOTA  46061        Hanson County                 0
# 2489          47     TENNESSEE  47155        Sevier County                 1
# 336           12       FLORIDA  12057  Hillsborough County                 1
# 3117          56       WYOMING  56033      Sheridan County                 0
#
#       month_started  mandate_duration_months        date        county  \
# 295               0                        0  2020-12-31          Weld
# 2384              0                        0  2020-12-31     Kingsbury
# 2691              7                        5  2020-12-31          Polk
# 914               0                        0  2020-12-31        Harper
# 1363              6                        6  2020-12-31        Ramsey
# 2375              0                        0  2020-12-31          Hand
# 2376              0                        0  2020-12-31        Hanson
# 2489              7                        5  2020-12-31        Sevier
# 336               6                        6  2020-12-31  Hillsborough
# 3117              0                        0  2020-12-31      Sheridan
#
#              state  cases  deaths  popestimate2020 e_results
# 295       Colorado  19925     285           333983         0
# 2384  South Dakota    538      13             4987         1
# 2691         Texas   2180      58            52995         1
# 914         Kansas    427      15             5336         1
# 1363     Minnesota  37111     688           547903         0
# 2375  South Dakota    312       2             3127         1
# 2376  South Dakota    311       3             3489         1
# 2489     Tennessee   8901      70            99244         1
# 336        Florida  77118    1071          1497957         1
# 3117       Wyoming   2543      17            30863         1

# %%
df.to_csv('final.csv')

# %%
# I don't think we need the rest of these codes as "final.csv" has all the information needed.
#elec_df1["state_name"] = elec_df1["state_name"].astype(str)
#elec_df1.dtypes

# %%
#df_complete = pd.merge(df, elec_df1, axis=0)
#df_complete.head()

# %%
#df_complete.head()

# %%
# Turn dataframe into a dictionary
#election_series = elec_df[["state_name", "red_blue_2020"]]
#key_value = election_series.set_index('state_name')['red_blue_2020'].to_dict()
#print(key_value)

# %%
#d = key_value.items()

#new_d = {str(key): str(value) for key, value in d}
#print(new_d)

# %%
#df['elec_result'] = df['state_name'].map(new_d)

# %%
#df.head()

# %%
#df

# %%
#df.dtypes
