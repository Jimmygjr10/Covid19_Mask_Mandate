# %%
import pandas as pd
import datetime as dt
df = "Resources/us-counties.csv"
df1 = pd.read_csv(df)
file = "Resources/county_mask_mandate_data.xlsx"
df2 = pd.read_excel(file)

# %% [markdown]
# ## Read in Both Datasets

# %%
df1.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22  Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23  Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24       Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24  Snohomish  Washington  53061.0      1     0.0

# %%
#Shows the data types for the df1
df1.dtypes
# Out:
# date       object
# county     object
# state      object
# fips      float64
# cases       int64
# deaths    float64
# dtype: object

# %%
# count the number of rows with empty columns
count = df1['fips'].isna().sum()
print(count)
# Out:
# 19744

# %%
#count the number of rows with data in each column
df1.count()
# Out:
# date      2135147
# county    2135147
# state     2135147
# fips      2115403
# cases     2135147
# deaths    2086356
# dtype: int64

# %%
# Drop the rows with blank data creating a new dataframe
df1_clean = df1.dropna()

# %%
# count the number of rows with data in each column from the clean dataframe
df1_clean.count()
# Out:
# date      2066612
# county    2066612
# state     2066612
# fips      2066612
# cases     2066612
# deaths    2066612
# dtype: int64

# %%
#change fips from float64 to int64 to match datatype of df1_clean "county_fips"
df1_clean['fips'].astype('int64')
# Out:
# 0          53061
# 1          53061
# 2          53061
# 3          17031
# 4          53061
#            ...
# 2135142    56037
# 2135143    56039
# 2135144    56041
# 2135145    56043
# 2135146    56045
# Name: fips, Length: 2066612, dtype: int64

# %%
# change deaths from float64 to int64 to match datatype of df1_clean "deaths"
df1_clean['deaths'].astype('int64')
# Out:
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
#           ...
# 2135142    114
# 2135143     14
# 2135144     34
# 2135145     41
# 2135146     16
# Name: deaths, Length: 2066612, dtype: int64

# %%
df1_clean['cases'].astype('int64')
# Out:
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
#            ...
# 2135142    9241
# 2135143    8741
# 2135144    4827
# 2135145    2022
# 2135146    1341
# Name: cases, Length: 2066612, dtype: int64

# %%
# Group by county to get the total_cases for each county, read the last day of 2020 as the total number of cases and deaths
df1_total = df1_clean.loc[df1_clean['date'] == "2020-12-31"]
df1_total.head()
# Out:
#               date   county    state    fips  cases  deaths
# 881492  2020-12-31  Autauga  Alabama  1001.0   4190    48.0
# 881493  2020-12-31  Baldwin  Alabama  1003.0  13601   161.0
# 881494  2020-12-31  Barbour  Alabama  1005.0   1514    32.0
# 881495  2020-12-31     Bibb  Alabama  1007.0   1834    46.0
# 881496  2020-12-31   Blount  Alabama  1009.0   4641    63.0

# %%
# Drop duplicates so only county shows once
df1_total = df1_total.drop_duplicates(subset=["fips"])
df1_total.head()
# Out:
#               date   county    state    fips  cases  deaths
# 881492  2020-12-31  Autauga  Alabama  1001.0   4190    48.0
# 881493  2020-12-31  Baldwin  Alabama  1003.0  13601   161.0
# 881494  2020-12-31  Barbour  Alabama  1005.0   1514    32.0
# 881495  2020-12-31     Bibb  Alabama  1007.0   1834    46.0
# 881496  2020-12-31   Blount  Alabama  1009.0   4641    63.0

# %% [markdown]
# ## DataSet 2 Mask Mandate

# %%
df2.head()
# Out:
#    state_fips state_name  county_fips           county_name county_start_date  \
# 0           1  ALABAMA           1067      Henry County                   NaT
# 1           1  ALABAMA           1071    Jackson County            2020-07-01
# 2           1  ALABAMA           1093     Marion County            2020-07-09
# 3           1  ALABAMA           1073  Jefferson County            2020-06-29
# 4           1  ALABAMA           1099     Monroe County                   NaT
#
#   county_end_date  county_conditions  \
# 0             NaN                NaN
# 1             NaN  all public places
# 2             NaN        retail only
# 3             NaN  all public places
# 4             NaN                NaN
#
#                                        county_source escalation defiance  \
# 0                                                NaN        NaN      NaN
# 1  https://www.examiner.net/news/20200629/jackson...        NaN      NaN
# 2  https://fox59.com/news/coronavirus/starting-to...        NaN      NaN
# 3  https://www.wbrc.com/2020/06/29/jefferson-coun...        NaN      NaN
# 4                                                NaN        NaN      NaN
#
#    county_start_edate state_start_date state_end_date   state_conditions  \
# 0                 NaN       07/16/2020     07/31/2020  all public places
# 1             22097.0       07/16/2020     07/31/2020  all public places
# 2             22105.0       07/16/2020     07/31/2020  all public places
# 3             22095.0       07/16/2020     07/31/2020  all public places
# 4                 NaN       07/16/2020     07/31/2020  all public places
#
#                                         state_source  state_start_edate  \
# 0  https://www.alabamapublichealth.gov/legal/asse...            22112.0
# 1  https://www.alabamapublichealth.gov/legal/asse...            22112.0
# 2  https://www.alabamapublichealth.gov/legal/asse...            22112.0
# 3  https://www.alabamapublichealth.gov/legal/asse...            22112.0
# 4  https://www.alabamapublichealth.gov/legal/asse...            22112.0
#
#    earliest_start_edate  county_fips_string earliest_start_date
# 0               22112.0                1067           7-16-2020
# 1               22097.0                1071            7-1-2020
# 2               22105.0                1093            7-9-2020
# 3               22095.0                1073           6-29-2020
# 4               22112.0                1099           7-16-2020

# %%
df2.dtypes
# Out:
# state_fips                       int64
# state_name                      object
# county_fips                      int64
# county_name                     object
# county_start_date       datetime64[ns]
# county_end_date                 object
# county_conditions               object
# county_source                   object
# escalation                      object
# defiance                        object
# county_start_edate             float64
# state_start_date                object
# state_end_date                  object
# state_conditions                object
# state_source                    object
# state_start_edate              float64
# earliest_start_edate           float64
# county_fips_string               int64
# earliest_start_date             object
# dtype: object

# %%
df2.count()
# Out:
# state_fips              3150
# state_name              3150
# county_fips             3150
# county_name             3149
# county_start_date       1500
# county_end_date          137
# county_conditions       1377
# county_source           1778
# escalation                34
# defiance                 203
# county_start_edate      1500
# state_start_date        1652
# state_end_date           504
# state_conditions        2045
# state_source            3150
# state_start_edate       1652
# earliest_start_edate    2103
# county_fips_string      3150
# earliest_start_date     2103
# dtype: int64

# %%
# Drop the unneeded columns 
df2_clean1 = df2.drop(['escalation', 'defiance', 'county_conditions', 'county_source', 'county_start_edate', 'state_start_edate', 'earliest_start_edate', 'county_fips_string', 'state_conditions', 'state_source'], axis=1)

df2_clean1.head()
# Out:
#    state_fips state_name  county_fips           county_name county_start_date  \
# 0           1  ALABAMA           1067      Henry County                   NaT
# 1           1  ALABAMA           1071    Jackson County            2020-07-01
# 2           1  ALABAMA           1093     Marion County            2020-07-09
# 3           1  ALABAMA           1073  Jefferson County            2020-06-29
# 4           1  ALABAMA           1099     Monroe County                   NaT
#
#   county_end_date state_start_date state_end_date earliest_start_date
# 0             NaN       07/16/2020     07/31/2020           7-16-2020
# 1             NaN       07/16/2020     07/31/2020            7-1-2020
# 2             NaN       07/16/2020     07/31/2020            7-9-2020
# 3             NaN       07/16/2020     07/31/2020           6-29-2020
# 4             NaN       07/16/2020     07/31/2020           7-16-2020

# %%
# Create our mask_mandate column with binary values Yes or No
no_mandate_df = df2_clean1[df2_clean1.county_start_date.isnull()]
mandate_df = df2_clean1[df2_clean1.county_start_date.notnull()]

# %%
# Create mask_mandate column
no_mandate_df["mask_mandate"] = "0"
mandate_df["mask_mandate"] = "1"
merged_df = no_mandate_df.append(mandate_df)
# Out:
# <ipython-input-18-71eab4377588>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_mandate_df["mask_mandate"] = "0"
# <ipython-input-18-71eab4377588>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mandate_df["mask_mandate"] = "1"

# %% [markdown]
# Show duration of mask mandate in 2020 only

# %%
# Create a null and not null dataset based on county start date
duration_df = merged_df[merged_df.county_start_date.notnull()]
duration_df1 = merged_df[merged_df.county_start_date.isnull()]
# Create a column that keeps up with month started 
duration_df['month_started'] = pd.DatetimeIndex(duration_df['county_start_date']).month
duration_df1['month_started'] = "0"
# Out:
# <ipython-input-19-dcd74a42da5f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duration_df['month_started'] = pd.DatetimeIndex(duration_df['county_start_date']).month
# <ipython-input-19-dcd74a42da5f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duration_df1['month_started'] = "0"

# %%
# Create a new column that is the difference between month started and total months in a year
duration_df["mandate_duration_months"] = (12 - duration_df.month_started)
duration_df1["mandate_duration_months"] = 0
final_df = duration_df.append(duration_df1)
# Out:
# <ipython-input-20-5f10596634b0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duration_df["mandate_duration_months"] = (12 - duration_df.month_started)
# <ipython-input-20-5f10596634b0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duration_df1["mandate_duration_months"] = 0

# %%
final_df
# Out:
#       state_fips state_name  county_fips            county_name  \
# 1              1  ALABAMA           1071     Jackson County
# 2              1  ALABAMA           1093      Marion County
# 3              1  ALABAMA           1073   Jefferson County
# 10             1  ALABAMA           1063      Greene County
# 23             1  ALABAMA           1089     Madison County
# ...          ...        ...          ...                    ...
# 3144          56  WYOMING          56011       Crook County
# 3145          56  WYOMING          56027    Niobrara County
# 3146          56  WYOMING          56015      Goshen County
# 3147          56  WYOMING          56029        Park County
# 3149          56  WYOMING          56017  Hot Springs County
#
#      county_start_date county_end_date state_start_date state_end_date  \
# 1           2020-07-01             NaN       07/16/2020     07/31/2020
# 2           2020-07-09             NaN       07/16/2020     07/31/2020
# 3           2020-06-29             NaN       07/16/2020     07/31/2020
# 10          2020-07-01             NaN       07/16/2020     07/31/2020
# 23          2020-07-07             NaN       07/16/2020     07/31/2020
# ...                ...             ...              ...            ...
# 3144               NaT             NaN              NaN            NaN
# 3145               NaT             NaN              NaN            NaN
# 3146               NaT             NaN              NaN            NaN
# 3147               NaT             NaN              NaN            NaN
# 3149               NaT             NaN              NaN            NaN
#
#      earliest_start_date mask_mandate month_started  mandate_duration_months
# 1               7-1-2020            1             7                        5
# 2               7-9-2020            1             7                        5
# 3              6-29-2020            1             6                        6
# 10              7-1-2020            1             7                        5
# 23              7-7-2020            1             7                        5
# ...                  ...          ...           ...                      ...
# 3144                 NaN            0             0                        0
# 3145                 NaN            0             0                        0
# 3146                 NaN            0             0                        0
# 3147                 NaN            0             0                        0
# 3149                 NaN            0             0                        0
#
# [3150 rows x 12 columns]

# %% [markdown]
# Add in election results

# %%
file = "Resources/elec_results_2020.csv"
dfe = pd.read_csv(file)

dfe.head()
# Out:
#    state_fips  state_name  red_blue_2020
# 0           1     ALABAMA              1
# 1           2      ALASKA              1
# 2           4     ARIZONA              0
# 3           5    ARKANSAS              1
# 4           6  CALIFORNIA              0

# %%
# merged_df2 = pd.merge(final_df, dfe, how="left", on=["state_name", "state_name"])
# merged_df2.head()
# Out:
#    state_fips_x state_name  county_fips           county_name  \
# 0             1  ALABAMA           1071    Jackson County
# 1             1  ALABAMA           1093     Marion County
# 2             1  ALABAMA           1073  Jefferson County
# 3             1  ALABAMA           1063     Greene County
# 4             1  ALABAMA           1089    Madison County
#
#   county_start_date county_end_date state_start_date state_end_date  \
# 0        2020-07-01             NaN       07/16/2020     07/31/2020
# 1        2020-07-09             NaN       07/16/2020     07/31/2020
# 2        2020-06-29             NaN       07/16/2020     07/31/2020
# 3        2020-07-01             NaN       07/16/2020     07/31/2020
# 4        2020-07-07             NaN       07/16/2020     07/31/2020
#
#   earliest_start_date mask_mandate month_started  mandate_duration_months  \
# 0            7-1-2020            1             7                        5
# 1            7-9-2020            1             7                        5
# 2           6-29-2020            1             6                        6
# 3            7-1-2020            1             7                        5
# 4            7-7-2020            1             7                        5
#
#    state_fips_y  red_blue_2020
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN

# %%
new_df = final_df.merge(dfe[["state_name","red_blue_2020"]], on="state_name", how="left")
new_df["red_blue_2020"] = new_df["red_blue_2020"]
new_df
# Out:
#       state_fips state_name  county_fips            county_name  \
# 0              1  ALABAMA           1071     Jackson County
# 1              1  ALABAMA           1093      Marion County
# 2              1  ALABAMA           1073   Jefferson County
# 3              1  ALABAMA           1063      Greene County
# 4              1  ALABAMA           1089     Madison County
# ...          ...        ...          ...                    ...
# 3145          56  WYOMING          56011       Crook County
# 3146          56  WYOMING          56027    Niobrara County
# 3147          56  WYOMING          56015      Goshen County
# 3148          56  WYOMING          56029        Park County
# 3149          56  WYOMING          56017  Hot Springs County
#
#      county_start_date county_end_date state_start_date state_end_date  \
# 0           2020-07-01             NaN       07/16/2020     07/31/2020
# 1           2020-07-09             NaN       07/16/2020     07/31/2020
# 2           2020-06-29             NaN       07/16/2020     07/31/2020
# 3           2020-07-01             NaN       07/16/2020     07/31/2020
# 4           2020-07-07             NaN       07/16/2020     07/31/2020
# ...                ...             ...              ...            ...
# 3145               NaT             NaN              NaN            NaN
# 3146               NaT             NaN              NaN            NaN
# 3147               NaT             NaN              NaN            NaN
# 3148               NaT             NaN              NaN            NaN
# 3149               NaT             NaN              NaN            NaN
#
#      earliest_start_date mask_mandate month_started  mandate_duration_months  \
# 0               7-1-2020            1             7                        5
# 1               7-9-2020            1             7                        5
# 2              6-29-2020            1             6                        6
# 3               7-1-2020            1             7                        5
# 4               7-7-2020            1             7                        5
# ...                  ...          ...           ...                      ...
# 3145                 NaN            0             0                        0
# 3146                 NaN            0             0                        0
# 3147                 NaN            0             0                        0
# 3148                 NaN            0             0                        0
# 3149                 NaN            0             0                        0
#
#       red_blue_2020
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3145            NaN
# 3146            NaN
# 3147            NaN
# 3148            NaN
# 3149            NaN
#
# [3150 rows x 13 columns]

# %%
# Split the county name into two columns NEEDS SOME WORK BECAUSE THERE ARE ARE SOME WITH MORE THAN ONE WORD AND END IN OTHER THINGS THAN COUNTY (BOROUGH, PARISH, CITY, CENSUS AREA)
# may not be needed if using FIP as the identifier

#df2_clean1['county'] = df2_clean1['county_name'].str.split(' ', expand=True)[0]
#df2_clean1['name'] = df2_clean1['county_name'].str.split(' ', expand=True)[1]

#df2_clean1.head()

# %%
# Drop the county_name column and the name column only leaving the county column with county name
#df2_clean2 = df2_clean1.drop(['county_name', 'name'], axis=1)

#df2_clean2.head()

# %%
#df2_clean2.dtypes

# %%
#df2_clean2.count()
